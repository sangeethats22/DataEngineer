# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeethats22/DataEngineer/blob/main/python/data_types%2Cstrings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# print a string

# %%
print("Sangeetha")
# Out:
# Sangeetha

# %%
print('''Sangeetha t s
python file''')
# Out:
# Sangeetha t s
# python file

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# Single-Line Comments

# %%
# This is a single-line comment
x = "Sangeetha TS"  # This is an inline comment
print(x)
# Out:
# Sangeetha TS

# %% [markdown]
# Multi-Line Comments

# %%
# Line 1 of comment
# Line 2 of comment

'''
This is a multi-line comment.
'''
# Out:
# '\nThis is a multi-line comment.\n'

# %% [markdown]
# Data types

# %%
Integer #a=4
float   #a=34.9
string  #a="sangeetha"
complex number #a=1+6j

# %% [markdown]
# Typecasting

# %%
value=20.76
int(value)
float(10)
str(value)
# Out:
# '20.76'

# %%
str(78)

# %%
a='name'
int(a) #cannot convert string to integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_921/342645744.py in <cell line: 0>()
#       1 a='name'
# ----> 2 int(a)
#
# ValueError: invalid literal for int() with base 10: 'name'

# %%
int('23') #a string / text containing numbers
# Out:
# 23

# %%
y=3+45j #complex number
type(y)
y.real
y.imag
# Out:
# 45.0

# %% [markdown]
# string slicing

# %%
#variable[start:stop:step]
x="Sangeetha TS"
print(x)
x[3:7]
# Out:
# Sangeetha TS
# 'geet'

# %%
x[3:10]

# %%
x[-8:-5]
# Out:
# 'eet'

# %%
x[-8:-1]
# Out:
# 'eetha T'

# %%
x[3:9:2]
# Out:
# 'geh'

# %%
x[-5:-3:1]
# Out:
# 'ha'

# %%
x[9:3:2] #Since moving forward from index 9 will never reach index 3
# Out:
# ''

# %% [markdown]
# Backward slicing

# %%
x[9:5:-1]
# Out:
# ' aht'

# %%
x[-5:-8:-1]
# Out:
# 'aht'

# %%
x[-5:-8:-1]
# Out:
# 'hte'

# %%
x[9:5:-1]
# Out:
# ' aht'

# %%
x[-2:-10:2] #Since moving forward from index -2 will never reach index -10
# Out:
# ''
