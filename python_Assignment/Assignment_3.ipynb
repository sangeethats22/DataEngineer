# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeethats22/DataEngineer/blob/main/python_Assignment/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
[bank = [
[
    [
        ["C101", "Rahul", "Savings", 85000],
        ["C102", "Anita", "Current", 150000],
        ["C103", "Kiran", "Loan", 500000]
    ],
    [
        ["C104", "Sneha", "Savings", 95000],
        ["C105", "Vikram", "Current", 275000],
        ["C106", "Meena", "Loan", 750000]
    ]
],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %%
#1. Print Rahul's complete record.
print(f'1.Rahul\'s complete record:{bank[0][0][0]}')

#2. Print Anita's account type.
print(f'2.Anita\'s account type: {bank[0][0][1][2]}')

#3. Print Kiran's loan amount.
print(bank[0][0][2][3])

#4. Print Sneha's customer ID.
print(bank[0][1][0][0])

#5. Print Vikram's balance.
print(bank[0][1][1][3])

#6. Print Meena's complete record.
print(bank[0][1][2])

#7. Print Arjun's customer ID.
print(bank[1][0][0][0])

#8. Print Pooja's name.
print(bank[1][0][1][1])

#9. Print Ramesh's account type.
print(bank[1][0][2][2])

#10. Print Priya's balance.
print(bank[1][1][0][3])

#11. Print Amit's account type.
print(bank[1][1][1][2])

#12. Print Divya's customer ID.
print(bank[1][1][2][0])

#13. Print Nikhil's account type.
print(bank[2][0][0][2])

#14. Print Kavya's balance.
print(bank[2][0][1][3])

#15. Print Suresh's loan amount.
print(bank[2][0][2][3])

#16. Print Neha's name.
print(bank[2][1][0][1])

#17. Print Rohan's complete record.
print(bank[2][1][1])

#18. Print Asha's account type.
print(bank[2][1][2][2])

#19. Print all customers in Bank 1, Branch 1.
print(bank[0][0])

#20. Print all customers in Bank 1, Branch 2.
print(bank[0][1])

#21. Print all customers in Bank 2, Branch 1.
print(bank[1][0])

#22. Print all customers in Bank 2, Branch 2.
print(bank[1][1])

#23. Print all customers in Bank 3, Branch 1.
print(bank[2][0])

#24. Print all customers in Bank 3, Branch 2.
print(bank[2][1])

#25. Print all branches of Bank 1.
print(bank[0])

#26. Print all branches of Bank 2.
print(bank[1])

#27. Print all branches of Bank 3.
print(bank[2])

#28. Print the first customer from every bank's first branch.
print(bank[0][0][0],bank[1][0][0],bank[2][0][0])

#29. Print the second customer from every bank's second branch.
print(bank[0][1][1],bank[1][1][1],bank[2][1][1])

#30. Print the loan amount of the last customer in Bank 3, Branch 2.
print(bank[2][1][2][3])
# Out:
# 1.Rahul's complete record:['C101', 'Rahul', 'Savings', 85000]2.Anita's account type: Current
# 500000
# C104
# 275000
# ['C106', 'Meena', 'Loan', 750000]
# C201
# Pooja
# Loan
# 45000
# Current
# C206
# Savings
# 240000
# 1000000
# Neha
# ['C305', 'Rohan', 'Current', 410000]
# Loan
# [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]
# [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]
# [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]
# [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]
# [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]
# [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]
# [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]
# [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]
# [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]
# ['C101', 'Rahul', 'Savings', 85000] ['C201', 'Arjun', 'Savings', 120000] ['C301', 'Nikhil', 'Savings', 78000]
# ['C105', 'Vikram', 'Current', 275000] ['C205', 'Amit', 'Current', 185000] ['C305', 'Rohan', 'Current', 410000]
# 550000

# %%
## Practice questions

# %%
# 1. Create a list of 5 employee names and add a new employee using `append()`.
emp_name= ['Sangeetha','Kushi','Ram','Sam','Paul']
emp_name.append('Anirudh')
print(emp_name)
# Out:
# ['Sangeetha', 'Kushi', 'Ram', 'Sam', 'Paul', 'Anirudh']

# %%
# 2. Create a list of account numbers and add three new account numbers using `extend()`.
acc_num= [1001,1002,1003,1004,1005]
acc_num.extend([1006,1007,1008])
print(acc_num)
# Out:
# [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008]

# %%
# 3. Insert a new customer at the beginning of a customer list using `insert()`.
cust_lst= ['C101','C102','C103','C104','C105']
cust_lst.insert(0,'C100')
print(cust_lst)
# Out:
# ['C100', 'C101', 'C102', 'C103', 'C104', 'C105']

# %%
# 4. Insert a transaction amount at index 3 in a list.
trans_amt= [1000,2000,3000,4000,5000]
trans_amt.insert(3,6000)
print(trans_amt)
# Out:
# [1000, 2000, 3000, 6000, 4000, 5000]

# %%
# 5. Remove the last item from a list using `pop()`.
trans_amt= [1000,2000,3000,4000,5000]
trans_amt.pop()
print(trans_amt)
# Out:
# [1000, 2000, 3000, 4000]

# %%
# 6. Remove the customer "Rahul" from a customer list using `remove()`.
cust_lst= ['Sangeetha','Kushi','Rahul','Sam','Paul']
cust_lst.remove('Rahul')
print(cust_lst)
# Out:
# ['Sangeetha', 'Kushi', 'Sam', 'Paul']

# %%
# 7. Count how many times the account type "Savings" appears in a list using `count()`.
acc_type= ['Savings','Current','Savings','Loan','Savings']
print(acc_type.count('Savings'))
# Out:
# 3

# %%
# 8. Find the index of "Current" in a list of account types using `index()`.
acc_type= ['Savings','Current','Savings','Loan','Savings']
print(acc_type.index('Current'))
# Out:
# 1

# %%
# 9. Reverse a list of transaction IDs using `reverse()`.
trans_id= [1001,1002,1003,1004,1005]
trans_id.reverse()
print(trans_id)
# Out:
# [1005, 1004, 1003, 1002, 1001]

# %%
# 10. Sort a list of account balances in ascending order using `sort()`.
acc_bal=[30000,10000,30000,20000,40000]
acc_bal.sort()
print(acc_bal)
# Out:
# [10000, 20000, 30000, 30000, 40000]

# %%
# 11. Sort a list of customer names in descending order using `sort()`.
cust_lst= ['Parul','Saageetha','Kushi','Sam','Rahul','Paul']
cust_lst.sort(reverse=True)
print(cust_lst)
cust_lst1=sorted(cust_lst,reverse=True)
print(cust_lst1)
# Out:
# ['Sam', 'Saageetha', 'Rahul', 'Paul', 'Parul', 'Kushi']
# ['Sam', 'Saageetha', 'Rahul', 'Paul', 'Parul', 'Kushi']

# %%
# 12. Make a copy of a list using `copy()` and verify that modifying the copied list does not affect the original list.
cust_lst= ['Parul','Saageetha','Kushi','Sam','Rahul','Paul']
new_cust_lst=cust_lst.copy()
new_cust_lst.append('Aman')
print(new_cust_lst)
print(cust_lst)
# Out:
# ['Parul', 'Saageetha', 'Kushi', 'Sam', 'Rahul', 'Paul', 'Aman']
# ['Parul', 'Saageetha', 'Kushi', 'Sam', 'Rahul', 'Paul']

# %%
# 13. Clear all elements from a list using `clear()`.
cust_lst= ['Parul','Saageetha','Kushi','Sam','Rahul','Paul']
cust_lst.clear()
print(cust_lst)
# Out:
# []

# %%
# 14. Append a nested list containing a new customer's details to an existing customer list.
cust_lst= ['Parul','Saageetha','Kushi','Sam','Rahul','Paul']
cust_lst.append(['sham',['sonu','Ram']])

'''new_cust_lst=['sham',['sonu','Ram']]
cust_lst.append(new_cust_lst)
print(cust_lst)'''
print(cust_lst)
# Out:
# ['Parul', 'Saageetha', 'Kushi', 'Sam', 'Rahul', 'Paul', ['sham', ['sonu', 'Ram']]]

# %%
# 15. Extend a list of branch names with another list of new branches.
branches=['Tumkur','Bengaluru','Mysore']
new_branches=['Hyderabad','sikkim','chennai']
branches.extend(new_branches)
branches.extend({'Hyderabad','sikkim','chennai'})
print(branches)
# Out:
# ['Tumkur', 'Bengaluru', 'Mysore', 'Hyderabad', 'sikkim', 'chennai', 'sikkim', 'Hyderabad', 'chennai']

# %%
# 16. Remove the first occurrence of the balance `50000` from a list using `remove()`.
balance= [10000,50000,20000,10000,30000,40000,50000]
balance.remove(50000)
print(balance)
# Out:
# [10000, 20000, 10000, 30000, 40000, 50000]

# %%
# 17. Pop the element at index 2 from a list and print the removed value.
balance= [10000,50000,20000,10000,30000,40000,50000]
removed_value=balance.pop(2)
print(removed_value)
print(balance)
# Out:
# 20000
# [10000, 50000, 10000, 30000, 40000, 50000]

# %%
# 18. Count how many times the city "Bangalore" appears in a list.
branches=['Tumkur','Bengaluru','Mysore','Bengaluru']
count_bengaluru=branches.count('Bengaluru')
print(f'bengaluru appears:{count_bengaluru} times')
# Out:
# bengaluru appears:2 times

# %%
# 19. Reverse a list of bank names and print the result.
bank_names=['RBI','ICICI','SBI','Karnataka Bank']
bank_names.reverse()
print(bank_names)
# Out:
# ['Karnataka Bank', 'SBI', 'ICICI', 'RBI']

# %%
# 20. Create a list of loan amounts and sort it in descending order.
loan_amt=[104000,780000,100000,400000,500000]
loan_amt.sort(reverse=True)
print(loan_amt)
# Out:
# [780000, 500000, 400000, 104000, 100000]

# %%
## Sample Sets
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}

loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}

transaction_ids = {101, 102, 103, 104, 105}

balances = {85000, 120000, 45000, 95000, 275000}

cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}

new_cities = {"Mumbai", "Bangalore", "Delhi"}

account_types = {"Savings", "Current", "Loan"}

# %%
### Basic Operations

# %%
# 1. Print the `customers` set.
print(f'customers set= {customers}')

# 2. Find the number of elements in the `customers` set.
print(f'number of elements in customers set= {len(customers)}')

# 3. Check whether "Rahul" exists in the `customers` set.
print(f'Rahul exists in customers set= {"Rahul" in customers}')
if 'Rahul' in customers:
   print('Rahul exists in customers set')
else:
  print('Rahul does not exists in customers set')

# 4. Check whether "Meena" exists in the `customers` set.
if 'Meena' in customers:
   print('Meena exists in customers set')
else:
  print('Meena does not exists in customers set')

# 5. Iterate through all elements in the `bank_branches` set.
print('elements in bank_branches = ')
for i in bank_branches:
  print(i)
# Out:
# customers set= {'Sneha', 'Rahul', 'Anita', 'Kiran', 'Vikram', 'Meena'}
# number of elements in customers set= 6
# Rahul exists in customers set= True
# Rahul exists in customers set
# Meena exists in customers set
# elements in bank_branches =
# Electronic City
# MG Road
# Indiranagar
# Whitefield

# %%
### add()

# %%
# 6. Add "Meena" to the `customers` set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.add('Meena')
print(f'updated customers set = {customers}')

# 7. Add "Mysore" to the `cities` set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.add('Mysore')
print(f'updated customers set = {cities}')
# Out:
# updated customers set = {'Sneha', 'Rahul', 'Anita', 'Kiran', 'Vikram', 'Meena'}
# updated customers set = {'Hyderabad', 'Mysore', 'Chennai', 'Pune', 'Bangalore'}

# %%
### update()

# %%
# 8. Update the `customers` set with `new_customers`.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.update(['Meena','Navya'])
print(f'updated customers set = {customers}')

# 9. Update the `cities` set with `new_cities`.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.update({'Tumkur','Mysore'})
print(f'updated customers set = {cities}')
# Out:
# updated customers set = {'Navya', 'Rahul', 'Sneha', 'Vikram', 'Meena', 'Kiran', 'Anita'}
# updated customers set = {'Pune', 'Chennai', 'Bangalore', 'Mysore', 'Tumkur', 'Hyderabad'}

# %%
### remove()

# %%
# 10. Remove "Rahul" from the `customers` set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.remove('Rahul')
print(f'updated customers set = {customers}')

# 11. Remove "Pune" from the `cities` set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.remove('Pune')
print(f'updated customers set = {cities}')

# %%
### discard()

# %%
# 12. Discard "Anita" from the `customers` set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
customers.discard('Anita')
print(f'updated customers set = {customers}')

# 13. Discard "Delhi" from the `cities` set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard('Delhi')
print(f'updated customers set = {cities}')

# 14. Discard "Kolkata" from the `cities` set.
cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}
cities.discard('Kolkata')
print(f'updated customers set = {cities}')
# Out:
# updated customers set = {'Sneha', 'Rahul', 'Kiran', 'Vikram'}
# updated customers set = {'Chennai', 'Hyderabad', 'Pune', 'Bangalore'}
# updated customers set = {'Chennai', 'Hyderabad', 'Pune', 'Bangalore'}

# %%
### pop()

# %%
# 15. Remove a random element from the `transaction_ids` set using `pop()`.
transaction_ids = {101, 102, 103, 104, 105}
print(transaction_ids.pop())
print(f'updated transaction_ids set = {transaction_ids}')

#16. Remove another random element from the `account_types` set.
account_types = {"Savings", "Current", "Loan"}
print(account_types.pop())
print(f'updated account_types set = {account_types}')
# Out:
# 101
# updated transaction_ids set = {102, 103, 104, 105}
# Savings
# updated account_types set = {'Current', 'Loan'}

# %%
### clear()

# %%
# 17. Remove all elements from the `balances` set.
balances = {85000, 120000, 45000, 95000, 275000}
balances.clear()
print(f'updated balances set = {balances}')
# Out:
# updated balances set = set()

# %%
### copy()

# %%
# 18. Create a copy of the `customers` set.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers=customers.copy()
print(f'new_customers set = {new_customers}')

#19. Modify the copied set and verify that the original set remains unchanged.
new_customers.add('Meena')
print(f'new_customers set = {new_customers}')
print(f'customers set = {customers}')
# Out:
# new_customers set = {'Kiran', 'Sneha', 'Rahul', 'Anita', 'Vikram'}
# new_customers set = {'Kiran', 'Sneha', 'Rahul', 'Meena', 'Anita', 'Vikram'}
# customers set = {'Kiran', 'Sneha', 'Rahul', 'Anita', 'Vikram'}

# %%
### union()

# %%
# 20. Find the union of `customers` and `new_customers`.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(f'union of customers and new_customers set = {customers.union(new_customers)}')
# Out:
# union of customers and new_customers set = {'Amit', 'Kiran', 'Divya', 'Anita', 'Rahul', 'Vikram', 'Sneha', 'Priya'}

# %%
# ### intersection()

# %%
# 21. Find the common customers between `customers` and `new_customers`.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(f'common customers between customers and new_customers set = {customers.intersection(new_customers)}')

# 22. Find customers who have both Savings and Loan accounts.
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
print(f'customers who have both Savings and Loan accounts = {loan_customers.intersection(savings_customers)}')
# Out:
# union of customers and new_customers set = {'Rahul'}
# customers who have both Savings and Loan accounts = {'Rahul'}

# %%
### difference()

# %%
# 23. Find customers present only in `customers` but not in `new_customers`.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(f'customers present only in customers but not in new_customers = {customers.difference(new_customers)}')

# 24. Find customers who have only Savings accounts.
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
print(f'customers who have only Savings accounts = {savings_customers.difference(loan_customers)}')
# Out:
# customers present only in customers but not in new_customers = {'Vikram', 'Anita', 'Kiran', 'Sneha'}
# customers who have only Savings accounts = {'Priya', 'Nikhil', 'Sneha'}

# %%
### symmetric_difference()

# %%
# 25. Find customers that are present in either `customers` or `new_customers` but not both.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
new_customers = {"Amit", "Priya", "Rahul", "Divya"}
print(f'customers that are present in either customers or new_customers but not both = {customers.symmetric_difference(new_customers)}')

# 26. Find customers who have Savings or Loan accounts but not both.
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}
print(f'customers who have Savings or Loan accounts but not both = {savings_customers.symmetric_difference(loan_customers)}')
# Out:
# customers that are present in either customers or new_customers but not both = {'Amit', 'Kiran', 'Divya', 'Anita', 'Vikram', 'Sneha', 'Priya'}
# customers who have Savings or Loan accounts but not both = {'Kiran', 'Nikhil', 'Sneha', 'Priya', 'Ramesh', 'Asha'}

# %%
### issubset()

#26. Check whether `{"Rahul", "Kiran"}` is a subset of `loan_customers`.
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
subset = {"Rahul", "Kiran"}
print(f'{"Rahul", "Kiran"} is a subset of loan_customers = {subset.issubset(loan_customers)}')
# Out:
# ('Rahul', 'Kiran') is a subset of loan_customers = True

# %%
### issuperset()

# 27. Check whether `customers` is a superset of `{"Rahul", "Anita"}`.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
superset = {"Rahul", "Anita"}
print(f'customers is a superset of {superset} = {customers.issuperset(superset)}')
# Out:
# customers is a superset of {'Anita', 'Rahul'} = True

# %%
### isdisjoint()

#28. Check whether `loan_customers` and `new_cities` are disjoint.
loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}
new_cities = {"Mumbai", "Bangalore", "Delhi"}
print(f'loan_customers and new_cities are disjoint = {loan_customers.isdisjoint(new_cities)}')
# Out:
# loan_customers and new_cities are disjoint = True

# %%
#29. Find the maximum balance in the `balances` set.
balances = {85000, 120000, 45000, 95000, 275000}
print(f'maximum balance in balances set = {max(balances)}')

#30. Find the minimum balance in the `balances` set.
balances = {85000, 120000, 45000, 95000, 275000}
print(f'minimum balance in balances set = {min(balances)}')

#31. Find the total of all balances.
balances = {85000, 120000, 45000, 95000, 275000}
print(f'sum of all balances = {sum(balances)}')

#32. Sort the `balances` set in ascending order.
balances = {85000, 120000, 45000, 95000, 275000}
print(f'sorted balances set = {sorted(balances)}')

#33. Convert the `customers` set into a list.
customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
list(customers)

#34. Convert the `cities` set into a tuple.
print(tuple(cities ))
# Out:
# maximum balance in balances set = 275000
# minimum balance in balances set = 45000
# sum of all balances = 620000
# sorted balances set = [45000, 85000, 95000, 120000, 275000]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_717/4283857084.py in <cell line: 0>()
#      17 #33. Convert the `customers` set into a list.
#      18 customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}
# ---> 19 list(customers)
#      20
#      21 #34. Convert the `cities` set into a tuple.
#
# TypeError: 'list' object is not callable

# %%
'''35. Remove duplicates from the a:`["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]`
    by converting it into a set.'''
List1=["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
print(set(List1))

#36. Create an empty set.


#37. Add five employee names to the empty set.


#38. Find the length of the `account_types` set.


#39. Print every element of the `loan_customers` set using a loop.


#40. Clear the `transaction_ids` set and verify that it is empty.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_717/2593796665.py in <cell line: 0>()
#       2     by converting it into a set.'''
#       3 List1=["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
# ----> 4 print(set(List1))
#       5
#       6 #36. Create an empty set.
#
# TypeError: 'dict' object is not callable
