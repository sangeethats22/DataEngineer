# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeethats22/DataEngineer/blob/main/python_Assignment/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "Edukron Data Science and Data Engineering Batch 2026"

# %%
#1. Write the indexing expression to print **"Edukron"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[0].center(11,'*')
# Out:
# '**Edukron**'

# %%
#Write the indexing expression to print **"Data"** (first occurrence).
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[1].center(8,'*')
# Out:
# '**Data**'

# %%
#Write the indexing expression to print **"Science"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[2].center(11,'*')
# Out:
# '**Science**'

# %%
#Write the indexing expression to print **"and"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[-5].center(7,'*')
# Out:
# '**and**'

# %%
#Write the indexing expression to print **"Data Engineering"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words1=words[-4]+' '+words[-3]
words1.center(len(words1)+4,'*')
# Out:
# '**Data Engineering**'

# %%
#Write the indexing expression to print **"Engineering"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[-3].center(len(words[-3])+4,'*')
# Out:
# '**Engineering**'

# %%
#Write the indexing expression to print **"Batch"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[-2].center(9,'*')
# Out:
# '**Batch**'

# %%
#Write the indexing expression to print **"2026"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words[-1].center(8,'*')
# Out:
# '**2026**'

# %%
#Write the indexing expression to print **"Science and Data"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
words=text.split()
words1=words[2]+' '+words[3]+' '+words[-4]
words1.center(len(words1)+4,'*')
# Out:
# '**Science and Data**'

# %%
#Write the indexing expression to print **"Data Science and Data Engineering Batch"**.
text = "Edukron Data Science and Data Engineering Batch 2026"
new_text=text.replace('Edukron ','')
new_text.center(len(new_text)+4,'*')
# Out:
# '**Data Science and Data Engineering Batch 2026**'
